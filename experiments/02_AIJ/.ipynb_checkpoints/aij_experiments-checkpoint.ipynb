# %% [markdown]
# # Ecai experiments

# %%
from pathlib import Path
import json
import sys
import subprocess
from collections import Counter
import matplotlib.pyplot as plt

# %%
def file_pprint_json(filename):
    with open(filename, 'r') as f:
        array = json.load(f)
    print(json.dumps(array, indent=4, sort_keys=True))

# %%
def read_print(filename):
    q = Path(filename)
    with q.open() as f: 
        s = f.readlines()
        #print(s)

# %%
def json2array(filename):
    with open(filename, 'r') as f:
        array = json.load(f)
    return array

# %%
def pprint_json(array):
    print(json.dumps(array, indent=4, sort_keys=False))

# %%
def filter_nested_explanations(explanation_array):
    '''Filters the explanations with nested explanations and for every nested explanations
    removes last step from reason_sequence and if nested_explanation is only 1 step it is removed
    as well.
    Remove also last step from nested explanation list.
    '''
    s_nested_explanation = "nested_explanations"
    s_reason_sequence = "reason_sequence"
    data_dict = {}
    
    # take explanations only with nested explanations
    expl_w_nested = [expl for expl in explanation_array if s_nested_explanation in expl]
    
    nested_2_more_steps = []
    
    # remove empty dict from nested_explanations
    for expl in expl_w_nested:
        expl[s_nested_explanation] = expl[s_nested_explanation][:-1]
    
    for expl in expl_w_nested:
        #pprint_json(expl)
        nested_explanations = []
        for seq in expl[s_nested_explanation]:
            seq[s_reason_sequence] = seq[s_reason_sequence][:-1]
            if len(seq[s_reason_sequence]) > 0:
                nested_explanations.append(seq.copy())
        #pprint_json(expl) 
        expl[s_nested_explanation] = nested_explanations
        #pprint_json(expl)
    
    expl_w_nested = [expl for expl in expl_w_nested if len(expl[s_nested_explanation]) > 0]

    return expl_w_nested

# %%
'''
dict['filename'] = {costs, clue, assumptions, derivations}

    data = {}
    
    data['costs'] = []
    data['clue'] = []
    data['assumptions'] =  []
    data['derivations'] =  []

    stats['cost'] = {}
    
    stats['cost']['costs_counter']
    stats['cost']['total_cost']
    stats['cost']['avg_cost']
    
    stats['clues'] = {}
    stats['clues']['clues_counter']
    stats['clues']['clues_successive_count']
'''
results = "./output"
p = Path(results)

ignored_files = ['p12.output.json', 'p13.output.json']
files = [x for x in p.iterdir() if x.is_file() and x.name not in ignored_files]

json_file = list(filter(lambda x: 'output.json' in x.name , files) )
#problems = list(filter(lambda x: 'nielspasta' in x.name or 'p5' in x.name , json_file))
file_paths = list(map(lambda f: f.absolute().as_posix(), json_file))
#print(file_paths)

#statistics = {}
data = {}

for i, fp in enumerate(file_paths):
    problem_name = json_file[i].name

    json_array = json2array(fp)
    data[problem_name] =  filter_nested_explanations(json_array)
    
    print(problem_name)
    pprint_json(data[problem_name])
#    statistics[problem_name] = build_statistics(data[problem_name])
# Out:
# p20.output.json
# [
#     {
#         "cost": "23",
#         "clue": "Of the home on Bird Road and Barnhill, one was visited in January and the other was haunted by Brunhilde",
#         "assumptions": [
#             {
#                 "pred": "haunted_by",
#                 "subject": "wolfenden",
#                 "object": "brunhilde",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "investigated_in",
#                 "subject": "barnhill",
#                 "object": "1",
#                 "value": true
#             },
#             {
#                 "pred": "on",
#                 "subject": "wolfenden",
#                 "object": "bird_road",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "investigated_in",
#                     "subject": "barnhill",
#                     "object": "1",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "wolfenden",
#                                 "object": "brunhilde",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "barnhill",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "hughenden",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "the_other_home",
#                                 "object": "brunhilde",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "derivable_fact": {
#                     "pred": "on",
#                     "subject": "wolfenden",
#                     "object": "bird_road",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "wolfenden",
#                                 "object": "brunhilde",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "barnhill",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "hughenden",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "the_other_home",
#                                 "object": "brunhilde",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "The home visited in April was either Markmanor or the home haunted by Brunhilde",
#         "assumptions": [
#             {
#                 "pred": "haunted_by",
#                 "subject": "markmanor",
#                 "object": "victor",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "4",
#                 "object": "abigail",
#                 "value": false
#             },
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "4",
#                 "object": "the_other_type2",
#                 "value": false
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "4",
#                     "object": "abigail",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "abigail",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "the_other_type2",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "victor",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "4",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "4",
#                     "object": "the_other_type2",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "the_other_type2",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "abigail",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "brunhilde",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "victor",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "4",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "The house haunted by Victor was visited 1 month after the house haunted by Lady Grey",
#         "assumptions": [
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "1",
#                 "object": "lady_grey",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "2",
#                 "object": "victor",
#                 "value": true
#             },
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "3",
#                 "object": "victor",
#                 "value": false
#             },
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "4",
#                 "object": "victor",
#                 "value": false
#             },
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "5",
#                 "object": "victor",
#                 "value": false
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "2",
#                     "object": "victor",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "lady_grey",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "lady_grey",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "3",
#                     "object": "victor",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "victor",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "lady_grey",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "lady_grey",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "4",
#                     "object": "victor",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "lady_grey",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "lady_grey",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "5",
#                     "object": "victor",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "victor",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "lady_grey",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "lady_grey",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "lady_grey",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "26",
#         "clue": "Markmanor was visited 1 month after the home on Grant Place",
#         "assumptions": [
#             {
#                 "pred": "haunted_by",
#                 "subject": "markmanor",
#                 "object": "victor",
#                 "value": true
#             },
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "2",
#                 "object": "victor",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_1",
#                 "subject": "1",
#                 "object": "grant_place",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_1",
#                     "subject": "1",
#                     "object": "grant_place",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "2",
#                                 "object": "victor",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "victor",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "1",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "1",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "victor",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "3",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "3",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "victor",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "4",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "4",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "haunted_by",
#                                 "subject": "markmanor",
#                                 "object": "victor",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "5",
#                                 "object": "victor",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "5",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "24",
#                         "clue": "Markmanor was visited 1 month after the home on Grant Place",
#                         "assumptions": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "3",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "4",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "5",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "investigated_in",
#                                 "subject": "markmanor",
#                                 "object": "2",
#                                 "value": true
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]
# p5-split.output.json
# [
#     {
#         "cost": "23",
#         "clue": "The Oregon native is either Zachary or the person who lives in Tehama",
#         "assumptions": [
#             {
#                 "pred": "lives_in",
#                 "subject": "roxanne",
#                 "object": "tehama",
#                 "value": false
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "from",
#                 "subject": "roxanne",
#                 "object": "oregon",
#                 "value": false
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "from",
#                     "subject": "roxanne",
#                     "object": "oregon",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "from",
#                                 "subject": "roxanne",
#                                 "object": "oregon",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "from",
#                                 "subject": "ernesto",
#                                 "object": "oregon",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "from",
#                                 "subject": "mattie",
#                                 "object": "oregon",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "from",
#                                 "subject": "the_other_native",
#                                 "object": "oregon",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "from",
#                                 "subject": "zachary",
#                                 "object": "oregon",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "Roxanne is 2 years younger than the Kansas native",
#         "assumptions": [
#             {
#                 "pred": "is_old",
#                 "subject": "roxanne",
#                 "object": "109",
#                 "value": false
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_1",
#                 "subject": "111",
#                 "object": "kansas",
#                 "value": false
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_1",
#                     "subject": "111",
#                     "object": "kansas",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_1",
#                                 "subject": "111",
#                                 "object": "kansas",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_1",
#                                 "subject": "109",
#                                 "object": "kansas",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_1",
#                                 "subject": "110",
#                                 "object": "kansas",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_1",
#                                 "subject": "112",
#                                 "object": "kansas",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_1",
#                                 "subject": "113",
#                                 "object": "kansas",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "The Oregon native is either Zachary or the person who lives in Tehama",
#         "assumptions": [
#             {
#                 "pred": "is_linked_with_3",
#                 "subject": "kansas",
#                 "object": "tehama",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "lives_in",
#                 "subject": "zachary",
#                 "object": "tehama",
#                 "value": false
#             },
#             {
#                 "pred": "from",
#                 "subject": "zachary",
#                 "object": "oregon",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "lives_in",
#                     "subject": "zachary",
#                     "object": "tehama",
#                     "value": false
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "kansas",
#                                 "object": "tehama",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "alaska",
#                                 "object": "tehama",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "oregon",
#                                 "object": "tehama",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "the_other_type1",
#                                 "object": "tehama",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "washington",
#                                 "object": "tehama",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "lives_in",
#                                 "subject": "zachary",
#                                 "object": "tehama",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "alaska",
#                                 "object": "tehama",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "from",
#                                 "subject": "zachary",
#                                 "object": "alaska",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "lives_in",
#                                 "subject": "zachary",
#                                 "object": "tehama",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "oregon",
#                                 "object": "tehama",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "from",
#                                 "subject": "zachary",
#                                 "object": "oregon",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "lives_in",
#                                 "subject": "zachary",
#                                 "object": "tehama",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "the_other_type1",
#                                 "object": "tehama",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "from",
#                                 "subject": "zachary",
#                                 "object": "the_other_type1",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "3",
#                         "clue": "Transitivity constraint",
#                         "assumptions": [
#                             {
#                                 "pred": "lives_in",
#                                 "subject": "zachary",
#                                 "object": "tehama",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "washington",
#                                 "object": "tehama",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "from",
#                                 "subject": "zachary",
#                                 "object": "washington",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "derivable_fact": {
#                     "pred": "from",
#                     "subject": "zachary",
#                     "object": "oregon",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "kansas",
#                                 "object": "tehama",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "alaska",
#                                 "object": "tehama",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "oregon",
#                                 "object": "tehama",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "the_other_type1",
#                                 "object": "tehama",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_3",
#                                 "subject": "washington",
#                                 "object": "tehama",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "The person who lives in Shaver Lake is 1 year younger than Roxanne",
#         "assumptions": [
#             {
#                 "pred": "is_old",
#                 "subject": "roxanne",
#                 "object": "112",
#                 "value": false
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "111",
#                 "object": "shaver_lake",
#                 "value": false
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "111",
#                     "object": "shaver_lake",
#                     "value": false
# ...
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "whitaker",
#                                 "object": "2011",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "whitaker",
#                                 "object": "2012",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "Gostroma was discovered 1 cycle after the comet discovered by Tillman",
#         "assumptions": [
#             {
#                 "pred": "is_linked_with_6",
#                 "subject": "tillman",
#                 "object": "2008",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "discovered_in",
#                 "subject": "gostroma",
#                 "object": "2009",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "discovered_in",
#                     "subject": "gostroma",
#                     "object": "2009",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2008",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2010",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2011",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2012",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "24",
#         "clue": "Of the comet discovered by Underwood and the comet with an orbital period of 42 years, one was found in 2009 and the other is Trosny",
#         "assumptions": [
#             {
#                 "pred": "is_linked_with_6",
#                 "subject": "parks",
#                 "object": "2009",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "discovered_by",
#                 "subject": "trosny",
#                 "object": "underwood",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "discovered_by",
#                     "subject": "trosny",
#                     "object": "underwood",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "parks",
#                                 "object": "2009",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "the_other_type1",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "underwood",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "whitaker",
#                                 "object": "2009",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "26",
#         "clue": "The comet with an orbital period of 21 years is either the comet discovered by Whitaker or Casputi",
#         "assumptions": [
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "21",
#                 "object": "whitaker",
#                 "value": false
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_1",
#                 "subject": "21",
#                 "object": "casputi",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_1",
#                     "subject": "21",
#                     "object": "casputi",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "24",
#                         "clue": "The comet with an orbital period of 21 years is either the comet discovered by Whitaker or Casputi",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "21",
#                                 "object": "whitaker",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "casputi",
#                                 "object": "whitaker",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "26",
#                         "clue": "The comet with an orbital period of 21 years is either the comet discovered by Whitaker or Casputi",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_1",
#                                 "subject": "21",
#                                 "object": "casputi",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "21",
#                                 "object": "whitaker",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "casputi",
#                                 "object": "parks",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "casputi",
#                                 "object": "the_other_type1",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "casputi",
#                                 "object": "tillman",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "casputi",
#                                 "object": "underwood",
#                                 "value": false
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "cost": "27",
#         "clue": "Of the comet discovered by Underwood and the comet with an orbital period of 42 years, one was found in 2009 and the other is Trosny",
#         "assumptions": [
#             {
#                 "pred": "is_linked_with_6",
#                 "subject": "parks",
#                 "object": "2009",
#                 "value": true
#             }
#         ],
#         "derivations": [
#             {
#                 "pred": "is_linked_with_2",
#                 "subject": "42",
#                 "object": "parks",
#                 "value": true
#             }
#         ],
#         "nested_explanations": [
#             {
#                 "derivable_fact": {
#                     "pred": "is_linked_with_2",
#                     "subject": "42",
#                     "object": "parks",
#                     "value": true
#                 },
#                 "reason_sequence": [
#                     {
#                         "cost": "2",
#                         "clue": "Bijectivity",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "parks",
#                                 "object": "2009",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "the_other_type1",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "tillman",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "underwood",
#                                 "object": "2009",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "whitaker",
#                                 "object": "2009",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "23",
#                         "clue": "Of the comet discovered by Underwood and the comet with an orbital period of 42 years, one was found in 2009 and the other is Trosny",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "underwood",
#                                 "object": "2009",
#                                 "value": false
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "trosny",
#                                 "object": "underwood",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "discovered_in",
#                                 "subject": "trosny",
#                                 "object": "2009",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "26",
#                         "clue": "Of the comet discovered by Underwood and the comet with an orbital period of 42 years, one was found in 2009 and the other is Trosny",
#                         "assumptions": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "42",
#                                 "object": "parks",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "parks",
#                                 "object": "2009",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "trosny",
#                                 "object": "parks",
#                                 "value": false
#                             }
#                         ]
#                     },
#                     {
#                         "cost": "27",
#                         "clue": "Of the comet discovered by Underwood and the comet with an orbital period of 42 years, one was found in 2009 and the other is Trosny",
#                         "assumptions": [
#                             {
#                                 "pred": "discovered_by",
#                                 "subject": "trosny",
#                                 "object": "underwood",
#                                 "value": true
#                             },
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "42",
#                                 "object": "parks",
#                                 "value": false
#                             },
#                             {
#                                 "pred": "is_linked_with_6",
#                                 "subject": "parks",
#                                 "object": "2009",
#                                 "value": true
#                             }
#                         ],
#                         "derivations": [
#                             {
#                                 "pred": "is_linked_with_2",
#                                 "subject": "42",
#                                 "object": "underwood",
#                                 "value": true
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
# Out:
# []

# %%
[]
