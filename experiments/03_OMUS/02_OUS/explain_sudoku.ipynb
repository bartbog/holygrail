# %%
import numpy as np
from cppy import *
from cppy.model_tools.to_cnf import *

# %%
# sudoku's, from http://hakank.org/minizinc/sudoku_problems2/index.html

sudoku_p0 = np.array([[0,0,0, 2,0,5, 0,0,0],
                      [0,9,0, 0,0,0, 7,3,0],
                      [0,0,2, 0,0,9, 0,6,0],
                      [2,0,0, 0,0,0, 4,0,9],
                      [0,0,0, 0,7,0, 0,0,0],
                      [6,0,9, 0,0,0, 0,0,1],
                      [0,8,0, 4,0,0, 1,0,0],
                      [0,6,3, 0,0,0, 0,8,0],
                      [0,0,0, 6,0,8, 0,0,0]])

# trivial version
sudoku_p0b = np.array([[0, 7, 8, 2, 6, 5, 9, 1, 4],
       [5, 9, 6, 8, 1, 4, 7, 3, 2],
       [1, 4, 2, 7, 3, 9, 5, 6, 8],
       [2, 1, 7, 3, 8, 6, 4, 5, 9],
       [8, 5, 4, 9, 7, 1, 6, 2, 3],
       [6, 3, 9, 5, 4, 2, 8, 7, 1],
       [7, 8, 5, 4, 2, 3, 1, 9, 6],
       [4, 6, 3, 1, 9, 7, 2, 8, 5],
       [9, 2, 1, 6, 5, 8, 3, 4, 7]])

# %%
from ortools.sat.python import cp_model

# model and solve a sudoku with ortools
def model_sudoku_ort(grid):
        csp = cp_model.CpModel()

        # init vars
        board = [[csp.NewIntVar(1, 9, 'x_%i%i' % (i,j)) for j in range(9)] for i in range(9)]
        
        # assign knowns
        for i in range(9):
            for j in range(9):
                if grid[i][j] != 0:
                    csp.Add(board[i][j] == grid[i][j])
        
        # all different rows
        for i in range(9):
            csp.AddAllDifferent(board[i])
        
        # all different columns
        for j in range(9):
            csp.AddAllDifferent([board[i][j] for i in range(9)])
        
        # all different cells
        for si in range(3):
            for sj in range(3):
                csp.AddAllDifferent([board[3*si+i][3*sj+j] for j in range(3) for i in range(3)])
        
        return csp, board
def solve_sudoku_ort(grid):
    # the constraint model and decision vars
    csp, x = model_sudoku_ort(grid)
    
    solver = cp_model.CpSolver()
    status = solver.Solve(csp) # or similar?
    solution = np.zeros((9,9), dtype=int)
    if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
        for i in range(9):
            for j in range(9):
                solution[i][j] = solver.Value(x[i][j])
        return solution 
    else:
        print("CSP infeasible")

sol = solve_sudoku_ort(sudoku_p0.tolist()) # grid must be plain python lists
sol
# Out:
# array([[3, 7, 8, 2, 6, 5, 9, 1, 4],
#        [5, 9, 6, 8, 1, 4, 7, 3, 2],
#        [1, 4, 2, 7, 3, 9, 5, 6, 8],
#        [2, 1, 7, 3, 8, 6, 4, 5, 9],
#        [8, 5, 4, 9, 7, 1, 6, 2, 3],
#        [6, 3, 9, 5, 4, 2, 8, 7, 1],
#        [7, 8, 5, 4, 2, 3, 1, 9, 6],
#        [4, 6, 3, 1, 9, 7, 2, 8, 5],
#        [9, 2, 1, 6, 5, 8, 3, 4, 7]])

# %%
# model and sudoku with cppy
given = sudoku_p0

# Variables
n = given.shape[0]
puzzle = IntVar(1, n, shape=given.shape)

constraint = []
# constraints on rows and columns
constraint += [ alldifferent(row) for row in puzzle ]
constraint += [ alldifferent(col) for col in puzzle.T ]

# constraint on blocks
for i in range(0,n,3):
    for j in range(0,n,3):
        constraint += [ alldifferent(puzzle[i:i+3, j:j+3]) ]

# constraints on values
constraint += [ puzzle[given>0] == given[given>0] ]

model = Model(constraint)
#stats = model.solve() # can't run minizinc in notebook
#print(stats)
#print(puzzle.value())

# %% [markdown]
# # We are solving the trivial case here!

# %%
# model and sudoku with cppy, Boolean style
given = sudoku_p0b

hardcons = []
softlits = []
givens = []

# Variables
n = given.shape[0]
puzzle = BoolVar(shape=(n,n,n)) # last dimension is values 1..9

# boolvars of givens
givens = []
for r in range(n):
    for c in range(n):
        if given[r,c] > 0:
            givens += [puzzle[r,c,given[r,c]-1]] # the positive
            givens += [~puzzle[r,c,e] for e in range(n) if e != given[r,c]-1] # the negatives       
#givens = [puzzle[r,c,given[r,c]-1] for r in range(n) for c in range(n) if given[r,c] > 0] # -1 cus offset 0
print(givens)

# each cell a unique value
bij_exists = [any(puzzle[i,j,:]) for i in range(n) for j in range(n)]
bij_nondbl = [(~puzzle[r,c,e1] | ~puzzle[r,c,e2]) for e1 in range(n) for e2 in range(e1+1,n) for r in range(n) for c in range(n)]
i1 = BoolVar()
hardcons += to_cnf([implies(i1, bijX) for bijX in bij_exists+bij_nondbl])
softlits += [i1]
print("grps:", len(softlits))

# each row different
for r in range(n):
    ralldiff = [any(puzzle[r,:,e]) for e in range(n)]
    ralldiff += [(~puzzle[r,j1,e] | ~puzzle[r,j2,e]) for e in range(n) for j1 in range(n) for j2 in range(j1,n) if j1 != j2]
    ri = BoolVar()
    hardcons += to_cnf([implies(ri, cons) for cons in ralldiff])
    softlits += [ri]
print("grps:", len(softlits))

# each col different
for c in range(n):
    calldiff = [any(puzzle[:,c,e]) for e in range(n)]
    calldiff += [(~puzzle[i1,c,e] | ~puzzle[i2,c,e]) for e in range(n) for i1 in range(n) for i2 in range(i1,n) if i1 != i2]
    ci = BoolVar()
    hardcons += to_cnf([implies(ci, cons) for cons in calldiff])
    softlits += [ci]
print("grps:", len(softlits))

## each block different
for i in range(0,n,3):
    for j in range(0,n,3):
        cblock = [any(puzzle[i1,j1,e] for i1 in range(i,i+3) for j1 in range(j,j+3)) for e in range(n)]
        cblock += [(~puzzle[i1,j1,e] | ~puzzle[i2,j2,e]) for e in range(n) for i1 in range(i,i+3) for i2 in range(i,i+3) for j1 in range(j,j+3) for j2 in range(j,j+3) if not(i1 == i2 and j1 == j2)]
        bi = BoolVar()
        hardcons += to_cnf([implies(bi, cons) for cons in cblock])
        softlits += [bi]
print("grps:", len(softlits))
# Out:
# [BV15, BV9 == 0, BV10 == 0, BV11 == 0, BV12 == 0, BV13 == 0, BV14 == 0, BV16 == 0, BV17 == 0, BV25, BV18 == 0, BV19 == 0, BV20 == 0, BV21 == 0, BV22 == 0, BV23 == 0, BV24 == 0, BV26 == 0, BV28, BV27 == 0, BV29 == 0, BV30 == 0, BV31 == 0, BV32 == 0, BV33 == 0, BV34 == 0, BV35 == 0, BV41, BV36 == 0, BV37 == 0, BV38 == 0, BV39 == 0, BV40 == 0, BV42 == 0, BV43 == 0, BV44 == 0, BV49, BV45 == 0, BV46 == 0, BV47 == 0, BV48 == 0, BV50 == 0, BV51 == 0, BV52 == 0, BV53 == 0, BV62, BV54 == 0, BV55 == 0, BV56 == 0, BV57 == 0, BV58 == 0, BV59 == 0, BV60 == 0, BV61 == 0, BV63, BV64 == 0, BV65 == 0, BV66 == 0, BV67 == 0, BV68 == 0, BV69 == 0, BV70 == 0, BV71 == 0, BV75, BV72 == 0, BV73 == 0, BV74 == 0, BV76 == 0, BV77 == 0, BV78 == 0, BV79 == 0, BV80 == 0, BV85, BV81 == 0, BV82 == 0, BV83 == 0, BV84 == 0, BV86 == 0, BV87 == 0, BV88 == 0, BV89 == 0, BV98, BV90 == 0, BV91 == 0, BV92 == 0, BV93 == 0, BV94 == 0, BV95 == 0, BV96 == 0, BV97 == 0, BV104, BV99 == 0, BV100 == 0, BV101 == 0, BV102 == 0, BV103 == 0, BV105 == 0, BV106 == 0, BV107 == 0, BV115, BV108 == 0, BV109 == 0, BV110 == 0, BV111 == 0, BV112 == 0, BV113 == 0, BV114 == 0, BV116 == 0, BV117, BV118 == 0, BV119 == 0, BV120 == 0, BV121 == 0, BV122 == 0, BV123 == 0, BV124 == 0, BV125 == 0, BV129, BV126 == 0, BV127 == 0, BV128 == 0, BV130 == 0, BV131 == 0, BV132 == 0, BV133 == 0, BV134 == 0, BV141, BV135 == 0, BV136 == 0, BV137 == 0, BV138 == 0, BV139 == 0, BV140 == 0, BV142 == 0, BV143 == 0, BV146, BV144 == 0, BV145 == 0, BV147 == 0, BV148 == 0, BV149 == 0, BV150 == 0, BV151 == 0, BV152 == 0, BV154, BV153 == 0, BV155 == 0, BV156 == 0, BV157 == 0, BV158 == 0, BV159 == 0, BV160 == 0, BV161 == 0, BV162, BV163 == 0, BV164 == 0, BV165 == 0, BV166 == 0, BV167 == 0, BV168 == 0, BV169 == 0, BV170 == 0, BV174, BV171 == 0, BV172 == 0, BV173 == 0, BV175 == 0, BV176 == 0, BV177 == 0, BV178 == 0, BV179 == 0, BV181, BV180 == 0, BV182 == 0, BV183 == 0, BV184 == 0, BV185 == 0, BV186 == 0, BV187 == 0, BV188 == 0, BV195, BV189 == 0, BV190 == 0, BV191 == 0, BV192 == 0, BV193 == 0, BV194 == 0, BV196 == 0, BV197 == 0, BV200, BV198 == 0, BV199 == 0, BV201 == 0, BV202 == 0, BV203 == 0, BV204 == 0, BV205 == 0, BV206 == 0, BV215, BV207 == 0, BV208 == 0, BV209 == 0, BV210 == 0, BV211 == 0, BV212 == 0, BV213 == 0, BV214 == 0, BV220, BV216 == 0, BV217 == 0, BV218 == 0, BV219 == 0, BV221 == 0, BV222 == 0, BV223 == 0, BV224 == 0, BV230, BV225 == 0, BV226 == 0, BV227 == 0, BV228 == 0, BV229 == 0, BV231 == 0, BV232 == 0, BV233 == 0, BV241, BV234 == 0, BV235 == 0, BV236 == 0, BV237 == 0, BV238 == 0, BV239 == 0, BV240 == 0, BV242 == 0, BV244, BV243 == 0, BV245 == 0, BV246 == 0, BV247 == 0, BV248 == 0, BV249 == 0, BV250 == 0, BV251 == 0, BV252, BV253 == 0, BV254 == 0, BV255 == 0, BV256 == 0, BV257 == 0, BV258 == 0, BV259 == 0, BV260 == 0, BV267, BV261 == 0, BV262 == 0, BV263 == 0, BV264 == 0, BV265 == 0, BV266 == 0, BV268 == 0, BV269 == 0, BV272, BV270 == 0, BV271 == 0, BV273 == 0, BV274 == 0, BV275 == 0, BV276 == 0, BV277 == 0, BV278 == 0, BV286, BV279 == 0, BV280 == 0, BV281 == 0, BV282 == 0, BV283 == 0, BV284 == 0, BV285 == 0, BV287 == 0, BV293, BV288 == 0, BV289 == 0, BV290 == 0, BV291 == 0, BV292 == 0, BV294 == 0, BV295 == 0, BV296 == 0, BV300, BV297 == 0, BV298 == 0, BV299 == 0, BV301 == 0, BV302 == 0, BV303 == 0, BV304 == 0, BV305 == 0, BV310, BV306 == 0, BV307 == 0, BV308 == 0, BV309 == 0, BV311 == 0, BV312 == 0, BV313 == 0, BV314 == 0, BV323, BV315 == 0, BV316 == 0, BV317 == 0, BV318 == 0, BV319 == 0, BV320 == 0, BV321 == 0, BV322 == 0, BV331, BV324 == 0, BV325 == 0, BV326 == 0, BV327 == 0, BV328 == 0, BV329 == 0, BV330 == 0, BV332 == 0, BV337, BV333 == 0, BV334 == 0, BV335 == 0, BV336 == 0, BV338 == 0, BV339 == 0, BV340 == 0, BV341 == 0, BV345, BV342 == 0, BV343 == 0, BV344 == 0, BV346 == 0, BV347 == 0, BV348 == 0, BV349 == 0, BV350 == 0, BV359, BV351 == 0, BV352 == 0, BV353 == 0, BV354 == 0, BV355 == 0, BV356 == 0, BV357 == 0, BV358 == 0, BV366, BV360 == 0, BV361 == 0, BV362 == 0, BV363 == 0, BV364 == 0, BV365 = ...
# grps: 1
# grps: 10
# grps: 19
# grps: 28

# %%
def visu_int2d(m, puzzle):
    boolarr = np.array([b in m for b in [e for lst in cnf_to_pysat(puzzle.tolist()) for e in lst]]).reshape(puzzle.shape)
    n = puzzle.shape[0]
    mtrx = np.zeros((n,n))
    for i in range(n):
        for j in range(n):
            idx = np.where(boolarr[i,j])[0]
            #print(idx)
            if len(idx) != 1:
                print(f"Err: m[{i},{j}] has {len(idx)} true values")
            else:
                mtrx[i,j] = idx[0]+1
    print(mtrx)

# %%
# lets solve it...
# pysat imports
from pysat.formula import CNF
from pysat.solvers import Solver

cnf = cnf_to_pysat(softlits + givens + hardcons)
with Solver(bootstrap_with=cnf) as s:
    sat = s.solve()
    print(sat)
    prev = None
    for id, m in enumerate(s.enum_models()):
            print(f"{id}: model found")
            visu_int2d(m, puzzle)
            #print(np.array(m).reshape(n,n,n))
            if not prev is None:
                print("diff", sorted(set(prev) - set(m), key=lambda l: abs(l)))
                break
            prev = m
# Out:
# True
# 0: model found
# [[3. 7. 8. 2. 6. 5. 9. 1. 4.]
#  [5. 9. 6. 8. 1. 4. 7. 3. 2.]
#  [1. 4. 2. 7. 3. 9. 5. 6. 8.]
#  [2. 1. 7. 3. 8. 6. 4. 5. 9.]
#  [8. 5. 4. 9. 7. 1. 6. 2. 3.]
#  [6. 3. 9. 5. 4. 2. 8. 7. 1.]
#  [7. 8. 5. 4. 2. 3. 1. 9. 6.]
#  [4. 6. 3. 1. 9. 7. 2. 8. 5.]
#  [9. 2. 1. 6. 5. 8. 3. 4. 7.]]

# %%
# lets explain it...
import explain

def flat(ll):
    return [e for l in ll for e in l]

params = explain.COusParams()
params.pre_seeding = True
params.polarity = True
params.grow = True
params.grow_maxsat = True
params.grow_maxsat_unit = True

cnfcnf = CNF(from_clauses=cnf_to_pysat(hardcons))
I = set(flat(cnf_to_pysat(givens+softlits)))
user_pos = set(flat(cnf_to_pysat(puzzle.flat)))
user_vars = I | user_pos | set([-e for e in user_pos])
# needs much better cost function: positive puzzles cheaper than negative, constraints more exp, bij cheaper than cons
f = lambda x: 1 # all unit

explain.explain(C=cnfcnf, U=user_vars, f=f, I0=I, params=params, verbose=True)
# Out:
# Expl:
# 	cnf: 14904 757
# 	U: 1486
# 	f: <function <lambda> at 0x7f2e9648af28>
# 	I0: 748
# {3, 16, 26, 29, 42, 50, 63, 64, 76, 86, 99, 105, 116, 118, 130, 142, 147, 155, 163, 175, 182, 196, 201, 216, 221, 231, 242, 245, 253, 268, 273, 287, 294, 301, 311, 324, 332, 338, 346, 360, 367, 370, 384, 389, 399, 411, 417, 432, 437, 445, 452, 467, 475, 478, 493, 503, 509, 517, 524, 534, 541, 558, 564, 571, 582, 588, 595, 612, 619, 623, 638, 644, 657, 659, 667, 681, 689, 701, 705, 715, 727, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, -729, -728, -726, -725, -724, -723, -722, -721, -720, -719, -718, -717, -716, -714, -713, -712, -711, -710, -709, -708, -707, -706, -704, -703, -702, -700, -699, -698, -697, -696, -695, -694, -693, -692, -691, -690, -688, -687, -686, -685, -684, -683, -682, -680, -679, -678, -677, -676, -675, -674, -673, -672, -671, -670, -669, -668, -666, -665, -664, -663, -662, -661, -660, -658, -656, -655, -654, -653, -652, -651, -650, -649, -648, -647, -646, -645, -643, -642, -641, -640, -639, -637, -636, -635, -634, -633, -632, -631, -630, -629, -628, -627, -626, -625, -624, -622, -621, -620, -618, -617, -616, -615, -614, -613, -611, -610, -609, -608, -607, -606, -605, -604, -603, -602, -601, -600, -599, -598, -597, -596, -594, -593, -592, -591, -590, -589, -587, -586, -585, -584, -583, -581, -580, -579, -578, -577, -576, -575, -574, -573, -572, -570, -569, -568, -567, -566, -565, -563, -562, -561, -560, -559, -557, -556, -555, -554, -553, -552, -551, -550, -549, -548, -547, -546, -545, -544, -543, -542, -540, -539, -538, -537, -536, -535, -533, -532, -531, -530, -529, -528, -527, -526, -525, -523, -522, -521, -520, -519, -518, -516, -515, -514, -513, -512, -511, -510, -508, -507, -506, -505, -504, -502, -501, -500, -499, -498, -497, -496, -495, -494, -492, -491, -490, -489, -488, -487, -486, -485, -484, -483, -482, -481, -480, -479, -477, -476, -474, -473, -472, -471, -470, -469, -468, -466, -465, -464, -463, -462, -461, -460, -459, -458, -457, -456, -455, -454, -453, -451, -450, -449, -448, -447, -446, -444, -443, -442, -441, -440, -439, -438, -436, -435, -434, -433, -431, -430, -429, -428, -427, -426, -425, -424, -423, -422, -421, -420, -419, -418, -416, -415, -414, -413, -412, -410, -409, -408, -407, -406, -405, -404, -403, -402, -401, -400, -398, -397, -396, -395, -394, -393, -392, -391, -390, -388, -387, -386, -385, -383, -382, -381, -380, -379, -378, -377, -376, -375, -374, -373, -372, -371, -369, -368, -366, -365, -364, -363, -362, -361, -359, -358, -357, -356, -355, -354, -353, -352, -351, -350, -349, -348, -347, -345, -344, -343, -342, -341, -340, -339, -337, -336, -335, -334, -333, -331, -330, -329, -328, -327, -326, -325, -323, -322, -321, -320, -319, -318, -317, -316, -315, -314, -313, -312, -310, -309, -308, -307, -306, -305, -304, -303, -302, -300, -299, -298, -297, -296, -295, -293, -292, -291, -290, -289, -288, -286, -285, -284, -283, -282, -281, -280, -279, -278, -277, -276, -275, -274, -272, -271, -270, -269, -267, -266, -265, -264, -263, -262, -261, -260, -259, -258, -257, -256, -255, -254, -252, -251, -250, -249, -248, -247, -246, -244, -243, -241, -240, -239, -238, -237, -236, -235, -234, -233, -232, -230, -229, -228, -227, -226, -225, -224, -223, -222, -220, -219, -218, -217, -215, -214, -213, -212, -211, -210, -209, -208, -207, -206, -205, -204, -203, -202, -200, -199, -198, -197, -195, -194, -193, -192, -191, -190, -189, -188, -187, -186, -185, -184, -183, -181, -180, -179, -178, -177, -176, -174, -173, -172, -171, -170, -169, -168, -167, -166, -165, -164, -162, -161, -160, -159, -158, -157, -156, -154, -153, -152, -151, -150, -149, -148, -146, -145, -144, -143, -141, -140, -139, -138, -137, -136, -135, -134, -133, -132, -131, -129, -128, -127, -126, -125, -124, -123, -122, -121, -120, -119, -117, -115, -114, -113, -112, -111, -110, -109, -108, -107, -106, -104, -103, -102, -101, -100, -98, -97, -96, -95, -94, -93, -92, -91, -90, -89, -88, -87, -85, -84, -83, -82, -81, -80, -79, -78, -77, - ...
# Using license file /home/tias/local/src/gurobi902/gurobi.lic
# Academic license - for non-commercial use only
# Warm start!
# Seeding 1 [9 remaining]
# Time grow {l}: 0 s
# Seeding 2 [7 remaining]
# Time grow {l}: 0 s
# Seeding 4 [6 remaining]
# Time grow {l}: 0 s
# Seeding 5 [5 remaining]
# Time grow {l}: 0 s
# Seeding 6 [4 remaining]
# Time grow {l}: 0 s
# Seeding 7 [3 remaining]
# Time grow {l}: 0 s
# Seeding 8 [2 remaining]
# Time grow {l}: 0 s
# Seeding 9 [1 remaining]
# Time grow {l}: 0 s
# Finished pre-seeding, tottime = 0 s
# 	MODE_OPT: got HS 2 cost 2.0 	MIP: 0.007 s	GROW: 0
# 	MODE_OPT: got HS 2 cost 2.0 	MIP: 0.004 s	GROW: 0.044
# 	MODE_OPT: got HS 2 cost 2.0 	MIP: 0.005 s	GROW: 0.048
# 	MODE_OPT: got HS 2 cost 2.0 	MIP: 0.005 s	GROW: 0.048
# 	MODE_OPT: got HS 2 cost 2.0 	MIP: 0.004 s	GROW: 0.161
# 	MODE_OPT: got HS 2 cost 2.0 	MIP: 0.01 s	GROW: 0.071
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.012 s	GROW: 0.059
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.009 s	GROW: 0.056
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.019 s	GROW: 0.052
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.007 s	GROW: 0.058
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.007 s	GROW: 0.047
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.012 s	GROW: 0.045
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.009 s	GROW: 0.056
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.008 s	GROW: 0.061
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.008 s	GROW: 0.048
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.008 s	GROW: 0.047
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.008 s	GROW: 0.047
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.009 s	GROW: 0.046
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.008 s	GROW: 0.072
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.009 s	GROW: 0.046
# texpl= 1.311 s
#
# 	#HS Opt: 20 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.169 s [13%]	 t/call= 0.008
# 	SAT=	 0.007 s [1%]	 t/call= 0.0
# 	GROW=	 1.114 s [85%]	 t/call= 0.056
#
# Optimal explanation 		 {64, 731} => {-1} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.016 s	GROW: 0
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.026 s	GROW: 0.054
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.016 s	GROW: 0.053
# texpl= 0.173 s
#
# 	#HS Opt: 3 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.059 s [34%]	 t/call= 0.015
# 	SAT=	 0.002 s [1%]	 t/call= 0.001
# 	GROW=	 0.106 s [61%]	 t/call= 0.035
#
# Optimal explanation 		 {749, 86} => {-5} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.016 s	GROW: 0
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.019 s	GROW: 0.06
# texpl= 0.101 s
#
# 	#HS Opt: 2 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.035 s [34%]	 t/call= 0.012
# 	SAT=	 0.002 s [2%]	 t/call= 0.001
# 	GROW=	 0.06 s [60%]	 t/call= 0.03
#
# Optimal explanation 		 {749, 175} => {-4} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.011 s	GROW: 0
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.101 s	GROW: 0.161
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.051 s	GROW: 0.153
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.011 s	GROW: 0.075
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.019 s	GROW: 0.045
# texpl= 0.643 s
#
# 	#HS Opt: 5 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.193 s [30%]	 t/call= 0.032
# 	SAT=	 0.007 s [1%]	 t/call= 0.001
# 	GROW=	 0.433 s [67%]	 t/call= 0.087
#
# Optimal explanation 		 {731, 29} => {-2} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.01 s	GROW: 0
# texpl= 0.015 s
#
# 	#HS Opt: 1 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.01 s [66%]	 t/call= 0.005
# 	SAT=	 0.001 s [10%]	 t/call= 0.001
#
# Optimal explanation 		 {16, 749} => {-7} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.02 s	GROW: 0
# texpl= 0.025 s
#
# 	#HS Opt: 1 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.02 s [80%]	 t/call= 0.01
# 	SAT=	 0.002 s [7%]	 t/call= 0.001
#
# Optimal explanation 		 {657, 740} => {-9} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.007 s	GROW: 0
# texpl= 0.011 s
#
# 	#HS Opt: 1 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.007 s [63%]	 t/call= 0.003
# 	SAT=	 0.001 s [13%]	 t/call= 0.001
#
# Optimal explanation 		 {26, 749} => {-8} 	 (cost: 2)
#
# 	MODE_OPT: got HS 3 cost 3.0 	MIP: 0.007 s	GROW: 0
# texpl= 0.012 s
#
# 	#HS Opt: 1 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.007 s [58%]	 t/call= 0.004
# 	SAT=	 0.002 s [15%]	 t/call= 0.001
# Optimal explanation 		 {105, 749} => {-6} 	 (cost: 2)
#
# 	MODE_OPT: got HS 5 cost 5.0 	MIP: 0.005 s	GROW: 0
# 	MODE_OPT: got HS 6 cost 6.0 	MIP: 0.008 s	GROW: 0.073
# 	MODE_OPT: got HS 6 cost 6.0 	MIP: 0.005 s	GROW: 0.078
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.014 s	GROW: 0.053
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.009 s	GROW: 0.055
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.008 s	GROW: 0.055
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.009 s	GROW: 0.044
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.007 s	GROW: 0.05
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.011 s	GROW: 0.058
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.009 s	GROW: 0.044
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.01 s	GROW: 0.051
# 	MODE_OPT: got HS 7 cost 7.0 	MIP: 0.007 s	GROW: 0.089
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.053 s	GROW: 0.118
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.026 s	GROW: 0.116
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.044 s	GROW: 0.051
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.025 s	GROW: 0.053
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.026 s	GROW: 0.071
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.035 s	GROW: 0.073
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.031 s	GROW: 0.067
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.037 s	GROW: 0.094
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.011 s	GROW: 0.086
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.053 s	GROW: 0.057
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.012 s	GROW: 0.067
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.018 s	GROW: 0.065
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.014 s	GROW: 0.062
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.013 s	GROW: 0.057
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.014 s	GROW: 0.055
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.025 s	GROW: 0.069
# 	MODE_OPT: got HS 8 cost 8.0 	MIP: 0.018 s	GROW: 0.05
# texpl= 2.464 s
#
# 	#HS Opt: 29 	 Incr: 0 	Greedy: 0
#
# 	MIP=	 0.559 s [23%]	 t/call= 0.019
# 	SAT=	 0.017 s [1%]	 t/call= 0.001
# 	GROW=	 1.86 s [76%]	 t/call= 0.064
#
# Optimal explanation 		 {201, -21, 749, 147, -12, 732, 733} => {3} 	 (cost: 7)
#
# [{'constraints': [64, 731], 'derived': [-1]}, {'constraints': [749, 86], 'derived': [-5]}, {'constraints': [749, 175], 'derived': [-4]}, {'constraints': [731, 29], 'derived': [-2]}, {'constraints': [16, 749], 'derived': [-7]}, {'constraints': [657, 740], 'derived': [-9]}, {'constraints': [26, 749], 'derived': [-8]}, {'constraints': [105, 749], 'derived': [-6]}, {'constraints': [201, -21, 749, 147, -12, 732, 733], 'derived': [3]}]
# [{'constraints': [64, 731], 'derived': [-1]},
#  {'constraints': [749, 86], 'derived': [-5]},
#  {'constraints': [749, 175], 'derived': [-4]},
#  {'constraints': [731, 29], 'derived': [-2]},
#  {'constraints': [16, 749], 'derived': [-7]},
#  {'constraints': [657, 740], 'derived': [-9]},
#  {'constraints': [26, 749], 'derived': [-8]},
#  {'constraints': [105, 749], 'derived': [-6]},
#  {'constraints': [201, -21, 749, 147, -12, 732, 733], 'derived': [3]}]

# %%
# the helper function below DOES NOT WORK, to be done in the CPpy future perhaps...
def alldifferent_bool(m):
    # assumption: dim0 = different variables, dim1 = boolvar for each value
    (nv,nb) = m.shape
    return [(~puzzle[j1,e] | ~puzzle[j2,e]) for e in range(nb) for j1 in range(nv) for j2 in range(nv) if j1 != j2]
#alldifferent_bool(puzzle[r,:,:])
